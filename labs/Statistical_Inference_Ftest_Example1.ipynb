# %% [markdown]
# # The F-Test (First Example)

# %% [markdown]
# ### Intro and objectives
#
#
# ### In this lab you will learn:
# 1. examples of multiple regression models.
# 2. how to fit multiple regression models in Python.
# 3. How to conduct F-Tests.
#
#
# ## What I hope you'll get out of this lab
# * The feeling that you'll "know where to start" when you need to fit a multiple regression model.
# * Worked Examples of multiple regression models
# * How to interpret the results obtained

# %%
# !pip install wooldridge

import wooldridge as woo
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wooldridge in /usr/local/lib/python3.7/dist-packages (0.4.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from wooldridge) (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->wooldridge) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->wooldridge) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->wooldridge) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->wooldridge) (1.15.0)

# %% [markdown]
# # Example 1. Determinants of salaries in the major baseball league

# %% [markdown]
# #### In this case we fit a multiple linear models to predict salaries in terms of a series of factors including years in the league, games played per year, batting average, home runs and runs batted per year
#
# $ log(salary)=\beta_0+\beta_1*years+\beta_2*gamesyr+\beta_3*bavg+\beta_4*hrunsyr+\beta_5*rbisyr+u $

# %% [markdown]
# ### Using the data in MLB1 where n=353 individuals

# %%
salaries = woo.dataWoo('mlb1')

# %%
salaries.head()
# Out:
#       salary     teamsal  nl  years  games  atbats  runs  hits  doubles  \
# 0  6329213.0  38407380.0   1     12   1705    6705  1076  1939      320
# 1  3375000.0  38407380.0   1      8    918    3333   407   863      156
# 2  3100000.0  38407380.0   1      5    751    2807   370   840      148
# 3  2900000.0  38407380.0   1      8   1056    3337   405   816      143
# 4  1650000.0  38407380.0   1     12   1196    3603   437   928       19
#
#    triples  ...     runsyr   percwhte   percblck   perchisp     blckpb  \
# 0       67  ...  89.666664  70.277969  18.844229  10.877804   0.000000
# 1       38  ...  50.875000  70.277969  18.844229  10.877804  18.844229
# 2       18  ...  74.000000  70.277969  18.844229  10.877804   0.000000
# 3       18  ...  50.625000  70.277969  18.844229  10.877804   0.000000
# 4       16  ...  36.416668  70.277969  18.844229  10.877804  18.844229
#
#    hispph     whtepw     blckph  hisppb    lsalary
# 0     0.0  70.277969   0.000000     0.0  15.660686
# 1     0.0   0.000000  10.877804     0.0  15.031906
# 2     0.0  70.277969   0.000000     0.0  14.946913
# 3     0.0  70.277969   0.000000     0.0  14.880221
# 4     0.0   0.000000  10.877804     0.0  14.316286
#
# [5 rows x 47 columns]

# %%
salaries.describe()
# Out:
#              salary       teamsal          nl       years        games  \
# count  3.530000e+02  3.530000e+02  353.000000  353.000000   353.000000
# mean   1.345672e+06  3.079483e+07    0.475921    6.325779   648.424929
# std    1.407352e+06  8.722411e+06    0.500129    3.880142   538.697499
# min    1.090000e+05  8.854000e+06    0.000000    1.000000     7.000000
# 25%    2.536000e+05  2.455733e+07    0.000000    3.000000   230.000000
# 50%    6.750000e+05  3.413650e+07    0.000000    6.000000   520.000000
# 75%    2.250000e+06  3.779200e+07    1.000000    9.000000   930.000000
# max    6.329213e+06  4.286600e+07    1.000000   20.000000  2729.000000
#
#              atbats         runs         hits     doubles     triples  ...  \
# count    353.000000   353.000000   353.000000  353.000000  353.000000  ...
# mean    2168.592068   290.402266   584.736544  103.881020   16.733711  ...
# std     2025.059766   301.010915   575.378562  104.323511   21.533336  ...
# min        7.000000     1.000000     1.000000    0.000000    0.000000  ...
# 25%      632.000000    73.000000   164.000000   26.000000    3.000000  ...
# 50%     1585.000000   191.000000   419.000000   70.000000    9.000000  ...
# 75%     3071.000000   407.000000   818.000000  147.000000   23.000000  ...
# max    10554.000000  1570.000000  3025.000000  634.000000  142.000000  ...
#
#            runsyr    percwhte    percblck    perchisp      blckpb      hispph  \
# count  353.000000  330.000000  330.000000  330.000000  330.000000  330.000000
# mean    38.582988   72.631088   16.548926   10.819986    5.144886    2.004179
# std     23.862686   15.227258   13.668326    9.387961   11.109446    5.858419
# min      0.500000   20.296301    3.741786    0.540870    0.000000    0.000000
# 25%     18.600000   67.668961    8.007545    1.962080    0.000000    0.000000
# 50%     35.333332   74.131294   14.453978   10.877804    0.000000    0.000000
# 75%     55.888889   82.948860   18.755629   16.330647    7.986870    0.000000
# max    105.142860   94.696266   73.960030   31.037498   73.960030   31.037498
#
#            whtepw      blckph      hisppb     lsalary
# count  330.000000  330.000000  330.000000  353.000000
# mean    36.667635    2.931898    3.046493   13.492183
# std     37.637047    6.667690    8.415198    1.182466
# min      0.000000    0.000000    0.000000   11.599103
# 25%      0.000000    0.000000    0.000000   12.443514
# 50%     20.296301    0.000000    0.000000   13.422468
# 75%     73.642937    1.561949    0.000000   14.626441
# max     94.696266   31.037498   73.960030   15.660686
#
# [8 rows x 47 columns]

# %%
type(salaries)
# Out:
# pandas.core.frame.DataFrame

# %%
# OLS regression:
reg = smf.ols(
    formula='np.log(salary) ~ years + gamesyr + bavg + hrunsyr + rbisyr',
    data=salaries)

# %%
# We fit the model
results = reg.fit()

# %%
results.params
# Out:
# Intercept    11.192418
# years         0.068863
# gamesyr       0.012552
# bavg          0.000979
# hrunsyr       0.014429
# rbisyr        0.010766
# dtype: float64

# %% [markdown]
# ## Based on the previous we have fitted the following model:
#
# $ log(salary)=11.19+0.68*years+0.0125*gamesyr+0.00097*bavg+0.14*hrunsyr+0.0107*rbisyr+u $

# %% [markdown]
# ## F-Test of statistical significance
#
# #### We are interested in determining if, once years in the league and games per year have been controlled for, performance metrics (bavg, hrunsy, rbisyr) have no effect on salary.
#
# #### Essentially we want to test if productivity, measured by baseball statistics, has no effect on salary.
#
# #### This test corresponds to the following null hypothesis:
#
#  $H_0: Β_3=0,Β_4=0,Β_5=0 $

# %%
# automated F test:
hypotheses = ['bavg = 0', 'hrunsyr = 0', 'rbisyr = 0']
ftest = results.f_test(hypotheses)
fstat = ftest.statistic[0][0]
fpval = ftest.pvalue

# %%
print(f'F statistic: {fstat}\n')
print(f'F p-value: {fpval}\n')
# Out:
# F statistic: 9.550253521951879
#
# F p-value: 4.4737081398389455e-06

# %% [markdown]
# ### Based on the previous results:
#
# #### The F-statistic is large and its associated p-value is almost cero.
#
# #### Therefore we reject the null hypothesis that bavg, hrunsyr, rbisyr have no effect on salary
# ## Therefore performance metrics DO HAVE an impact on salary
